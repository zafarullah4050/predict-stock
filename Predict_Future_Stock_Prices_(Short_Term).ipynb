# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Download historical stock data
data = yf.download("AAPL", start="2022-01-01", end="2024-12-31")
data = data[['Open', 'High', 'Low', 'Close', 'Volume']]  # Select useful features
data.dropna(inplace=True)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
# Shift 'Close' column to get the next day's close as the label
data['Next_Close'] = data['Close'].shift(-1)

# Drop the last row (as it will have NaN for Next_Close)
data.dropna(inplace=True)

# Define features and target
X = data[['Open', 'High', 'Low', 'Volume']]
y = data['Next_Close']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

y_pred_lr = lr_model.predict(X_test)

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)

# %%
print("Random Forest Results:")
print("MSE:", mean_squared_error(y_test, y_pred_rf))
print("R² Score:", r2_score(y_test, y_pred_rf))
# Out:
# Random Forest Results:
# MSE: 1086.2099618110574
# R² Score: -4.42126042799228

# %%
plt.figure(figsize=(10,6))
plt.plot(y_test.values, label='Actual Close', color='blue')
plt.plot(y_pred_rf, label='Predicted Close', color='red')
plt.title('Actual vs Predicted Next Day Close Price (Random Forest)')
plt.xlabel('Days')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %%
import pickle

# %%
# Train the model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Save the trained model to disk
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
from sklearn.preprocessing import StandardScaler
import pickle

# Create and fit scaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_train)

# Save the scaler to disk
with open('scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)

# %%
from google.colab import files

# Download model.pkl
files.download('model.pkl')

# Download scaler.pkl
files.download('scaler.pkl')

# %%
# stock_app.py

import streamlit as st
import numpy as np
import pickle

# Page config
st.set_page_config(page_title="Stock Price Predictor", layout="centered")

# Load model and scaler
try:
    model = pickle.load(open('stock_model.pkl', 'rb'))
    scaler = pickle.load(open('stock_scaler.pkl', 'rb'))
except Exception as e:
    st.error(f"❌ Error loading model or scaler: {e}")
    st.stop()

# Title
st.title("📈 Stock Price Predictor")
st.markdown("Predict the **next day's closing price** using Open, High, Low, and Volume.")

# Sidebar inputs
st.sidebar.header("📥 Enter Stock Market Data")
open_price = st.sidebar.number_input("Open Price", value=150.00, format="%.2f")
high_price = st.sidebar.number_input("High Price", value=155.00, format="%.2f")
low_price = st.sidebar.number_input("Low Price", value=148.00, format="%.2f")
volume = st.sidebar.number_input("Volume", value=1000000)

# Predict button
if st.sidebar.button("Predict Close Price"):
    # Prepare input
    input_data = np.array([[open_price, high_price, low_price, volume]])
    input_scaled = scaler.transform(input_data)
    prediction = model.predict(input_scaled)

    # Show results
    st.subheader("📊 Predicted Next Close Price")
    st.success(f"${prediction[0]:.2f}")

    st.subheader("🔍 Input Summary")
    st.write(f"**Open:** ${open_price}")
    st.write(f"**High:** ${high_price}")
    st.write(f"**Low:** ${low_price}")
    st.write(f"**Volume:** {volume}")
# Out:
# 2025-06-15 04:44:15.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.367 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-15 04:44:15.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
app_code = '''<paste the full code string here as triple quotes>'''

with open('app.py', 'w') as f:
    f.write(app_code)

from google.colab import files
files.download('app.py')
